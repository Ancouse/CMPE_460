# %% [markdown]
# ## Week 8 - Word2VecFile
# ! it is actually midterm week but i'm gonna use lectures
# * <span style="color:red">Word2VecFile</span>
# <br>
#
#     * Idea : Learn an embedding from words into vectors
#     * Need to have a function W(word) that returns a vector encoding that word
#
# ! Hocanın paylaştığı ipynb dosyası üzerinden örnek yapabilirsin. Sadece Kopyala yapıştır ama nasıl işlediğini anlamalısın!!

# %% [markdown]
#  <span style="color:red">Kendi Düşüncem</span>
#
# * Bu konu kelimelerin birbirine yakınlığı ve arasındaki ilişkileri incelememize yarıyor.
# * "Merhaba" kelimesinin hangi kelimlere daha yakın olduğunu bulmaya çalışmakta bir örnektir.
#     * Mesela, Merhaba günaydın, Merhaba kanka, Merhaba ... gibi örneklerle. Test case'imizdeki prediction yapabiliriz.
#     * Kelimerin "FREKANSI" üzerine çalışıyoruz demek daha doğru olacaktır.
#     * Bu frekanslardan yola çıkarak diğer kelimelerin frekansları ile bir uyum yakalamak.
#
# <br>
#
# <span style="color:green">Word2Vec Dosyasına bak !!</span>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('pictures/example.png')
plt.imshow(img)
plt.title("picture 1")
plt.show()

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt


img = mpimg.imread('pictures/Word2vec.png')
plt.imshow(img)
plt.title("picture 2")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('pictures/word_embeding.png')
plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('pictures/picture4.png')
plt.imshow(img)
plt.show()

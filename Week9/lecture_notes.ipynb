# %% [markdown]
# # Word Embeding Word2Vec Nedir ?
#
# Buradaki asıl amaç kelimeleri bir bilgisayarın anlayabileceği bir hale getirmektir. Benzer kelimeleri birbirine yakın koyuyoruz.
# Bunları sayı haline getiriyoruz diyebiliriz. Burada yaptığımızda kelimerlin birbirien yakın olup olmadığına bakıyor word2vec.
#
# Tek tek elle atanabilir ama bu çok uzun sürer ondan encoder kullanıyoruz. Inputu veriyoruz ve yakınındaki kelimeyi tahmin etmesini bekliyoruz. Sonuç olarak bize kelimelerin text içerisindeki yakınlıklarını vermiş oluyor.
#
# Kulaktan kulağa oyununa çok benziyor. ilk kişi kelimeyi alıyor. İkinci kişiye iletip kendince değiştiriyor(weight and bias) böyle devam ediyor.En son kişi ise söylediğinde kelimeyi öğrenmiş oluyoruz. Ya çok benziyor ama farklı tabi :D
#
# backforward -> weightleri bulmayı sağlıyor.
#
# Daha compat hale getirmek -> embeding
#
# Encoder ve Decoker Mantığı nedir ? -> araştır

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('pictures/Screenshot_1.png')
plt.imshow(img)
plt.title("picture 1")
plt.show()

# %%
img = mpimg.imread('pictures/Screenshot_2.png')
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('pictures/Screenshot_3.png')
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('pictures/Screenshot_5.png')
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('pictures/Screenshot_6.png')
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('pictures/Screenshot_7.png')
plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('pictures/Screenshot_8.png')
plt.imshow(img)
plt.show()

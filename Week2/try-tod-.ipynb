# %% [markdown]
# # Topics
# * Regression analysis
# * Linear Regression
# * Logistic REgression
#
# Bu week2 dosyası içindeki try başlıklı olanlar denemelerimdir.
# Okul ödevleri ile bir bağlantısı yoktur.

# %% [markdown]
# ## Regression analysis
#
# Regresyon analizi: bir bağımlı değişken ile bir veya daha fazla bağımsız değişken arasındaki ilişkileri tahmin etmedir.
#
# Bazı tanımlamaları var. "picture1"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('regression_model1.png')
plt.imshow(img)
plt.title("picture1")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('linear-regression_1.png')
plt.imshow(img)
plt.title("picture1")
plt.show()

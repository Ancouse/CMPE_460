# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 3 + rng.randn(50)
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y,color="red")
plt.plot(xfit, yfit)

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     2.0272088103606944
# Model intercept: -2.9985770855532

# %% [markdown]
# # 2.time

# %%
df = pd.read_csv("income.data.csv")
df
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
df = df.drop(["Unnamed: 0"],axis=1)
df.isnull().sum()
# Out:
# income       0
# happiness    0
# dtype: int64

# %%
plt.figure(figsize=(12, 5))
plt.plot(df["income"], df["happiness"], 'o', label='data')
plt.legend()

# %%
train_idx = df[:400]
# Uses the remaining indices for validation
val_idx = df[400:]

# %%
from sklearn.linear_model import LinearRegression

# Linear regression model
linear_reg = LinearRegression()
x=df.income.values.reshape(-1,1)
y = df.happiness.values.reshape(-1, 1)

linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
b0_ = linear_reg.intercept_
print("b0_:", b0_)  # y esksenini kestigi nokta

b1 = linear_reg.coef_
print("b1:", b1)  # egim slape/gradiant


for i in range(len(df)):
    happiness = b0_ + b1*df["income"][i] + 0.0018
    print(i,":",happiness)
# Out:
# b0_: [0.2042704]
# b1: [[0.71382551]]
# 0 : [[2.96332667]]
# 1 : [[3.76047986]]
# 2 : [[3.72091648]]
# 3 : [[2.50057145]]
# 4 : [[5.34305092]]
# 5 : [[2.86838506]]
# 6 : [[3.54286017]]
# 7 : [[3.41693166]]
# 8 : [[2.43436991]]
# 9 : [[3.51815969]]
# 10 : [[3.51310944]]
# 11 : [[2.18563624]]
# 12 : [[5.28813585]]
# 13 : [[5.53595794]]
# 14 : [[1.7177689]]
# 15 : [[2.03286825]]
# 16 : [[1.88698187]]
# 17 : [[1.91079797]]
# 18 : [[3.6007963]]
# 19 : [[1.6296348]]
# 20 : [[5.42478877]]
# 21 : [[2.72467448]]
# 22 : [[1.9397753]]
# 23 : [[2.73497421]]
# 24 : [[3.93738]]
# 25 : [[4.98298583]]
# 26 : [[2.99028252]]
# 27 : [[1.84148425]]
# 28 : [[1.9053411]]
# 29 : [[2.02604619]]
# 30 : [[5.15523384]]
# 31 : [[1.53067726]]
# 32 : [[2.76800668]]
# 33 : [[5.07898449]]
# 34 : [[1.68411885]]
# 35 : [[3.9352414]]
# 36 : [[1.80726213]]
# 37 : [[5.25721848]]
# 38 : [[3.19747934]]
# 39 : [[1.6026601]]
# 40 : [[3.81928253]]
# 41 : [[3.04865917]]
# 42 : [[2.39398744]]
# 43 : [[2.83500231]]
# ...

# %%
plt.figure(figsize=(12, 5))
plt.plot(df["income"], df["happiness"], 'o', label='data')
plt.plot(hp, 'ro', label='data')
plt.legend()
